# %% [markdown]
# # 국민은행_토스앱 리뷰 1년치 수집_저장_텍스트분석_mini_project
# * 1. google play에서 국민은행 스타뱅킹앱, 토스앱의 사용자 리뷰를 1년치 수집
# * 2. 수집한 리뷰를 mysql에 저장
# * 3. 수집된 데이터로 긍정/부정 리뷰 비율 분석(막대 그래프 비교)
# * 4. 워드클라우드 분석
# * 5. LDA 토픽 모델링 분석(최적 k 탐색 포함)
# * 6. word2vec 생성 후 T-sne 로 시각화
# * 7. 분석 결과를 통해 얻을 수 있는 인사이트(문제점, 개선방안) 보고서 작성

# %%
import pandas as pd
from dbio import from_db

# %%
toss_df = from_db("bank_app_reviews", "toss_reviews")
kb_df = from_db("bank_app_reviews", "kbbank_reviews")

toss_df["app"] = "토스"
kb_df["app"] = "국민은행"

reviews_df = pd.concat([toss_df, kb_df], ignore_index=True)

reviews_df.to_csv("bank_reviews_all.csv", index=False, encoding="utf-8-sig")

print("통합 CSV 저장 완료")
# Out:
# bank_app_reviews 데이터베이스 확인/생성 완료
# bank_app_reviews.toss_reviews 데이터 로드 완료
# bank_app_reviews 데이터베이스 확인/생성 완료
# bank_app_reviews.kbbank_reviews 데이터 로드 완료
# 통합 CSV 저장 완료

# %%
df = pd.read_csv("bank_reviews_all.csv")

print("원본:", len(df))

df = df.drop_duplicates(subset=["date","rating","review_text","app"])

print("중복 제거 후:", len(df))
# Out:
# 원본: 14049
# 중복 제거 후: 9889

# %%
train_df = df
train_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9889 entries, 0 to 9974
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         9889 non-null   str
#  1   rating       9889 non-null   int64
#  2   review_text  9889 non-null   str
#  3   app          9889 non-null   str
# dtypes: int64(1), str(3)
# memory usage: 386.3 KB

# %%
train_df = pd.read_csv("./bank_reviews_all.csv")
train_df
# Out:
#              date  rating                                        review_text  \
# 0      2026-03-05       1                용량 봐라...내 폰 자원 1기가 육박하게 잡아먹고 있네 ㅎ;;
# 1      2026-03-05       1  접속이 안됩니다. 특히 3일전부터 아예 안들어가지는 시간대가 너무 길고 잦아요. 다...
# 2      2026-03-05       1  업데이트하고 나서 왜 이체할 때 비밀번호 치는 창이 투명하게 뜨는 겁니까? 투명하게...
# 3      2026-03-05       3                                       폰트가 뭉게져서 나와요
# 4      2026-03-04       2             진짜 토스좋아하는데 요즘 에러도 자주나고 느려지고 아주 불편해요ㅜㅜㅜ
# ...           ...     ...                                                ...
# 14044  2025-03-05       5                             구미공단점 직원도움으러잘가입함. 매우만족
# 14045  2025-03-05       1  비대면 뱅킹 가입 인증이 다른 메이저 금융어플 보다 훨씬 복잡함. 주민등록초본 발급...
# 14046  2025-03-05       5                                            정말 편해요~
# 14047  2025-03-05       5                                           Ui가 편하네요
# 14048  2025-03-05       5                  너무쉽게 사용할수있도록해주는 너무좋은 앱 시스템 인것같습니다
#
#         app
# 0        토스
# 1        토스
# 2        토스
# 3        토스
# 4        토스
# ...     ...
# 14044  국민은행
# 14045  국민은행
# 14046  국민은행
# 14047  국민은행
# 14048  국민은행
#
# [14049 rows x 4 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
train_df['rating'].value_counts()
# Out:
# rating
# 5    3999
# 1    3726
# 3     817
# 4     756
# 2     591
# Name: count, dtype: int64

# %%
train_df[train_df['rating'] == 5]
# Out:
#             date  rating                                        review_text  \
# 7     2026-03-04       5  간단한 미션으로도 돈을벌수있고 소비복권같은 거랑 토스쇼핑에서 하는 이벤트 너무 유용...
# 25    2026-03-04       5  다 먹고 나오면 할인해준다고 알람뜨는거 킹받아서 어쩌면좋죠...? 사람 놀리는것도 ...
# 73    2026-03-03       5  다 좋은데 토스 행운복권 그거 매일 하는데 오늘부터 첫단계만 되고 나머지 단계로 안...
# 81    2026-03-03       5  고객센터에도 맨앞에 뜨긴 하는데.. 지금 토스 고양이 광고를 봐도 하나도 안 넘어가...
# 84    2026-03-03       5  요즘 결제 내역에서 지 맘대로 내역 수정하는 경우가 있어요. 3000원인데 취소선 ...
# ...          ...     ...                                                ...
# 9969  2025-03-05       5                                 이해하기쉽게 설명이 참고되어있네요
# 9970  2025-03-05       5                             구미공단점 직원도움으러잘가입함. 매우만족
# 9972  2025-03-05       5                                            정말 편해요~
# 9973  2025-03-05       5                                           Ui가 편하네요
# 9974  2025-03-05       5                  너무쉽게 사용할수있도록해주는 너무좋은 앱 시스템 인것같습니다
#
#        app
# 7       토스
# 25      토스
# 73      토스
# 81      토스
# 84      토스
# ...    ...
# 9969  국민은행
# 9970  국민은행
# 9972  국민은행
# 9973  국민은행
# 9974  국민은행
#
# [3999 rows x 4 columns]

# %%
train_df[train_df['rating'] == 4]
# Out:
#             date  rating                                        review_text  \
# 16    2026-03-04       4  비밀번호 입력할 때 번호판이 예전엔 검은 화면으로 바뀌면서 흰 색으로 떴는데 지금은...
# 29    2026-03-04       4  '자산 변화'에서 총자산으로 설정한 금액으로 "그래프에서도 동일하게 월변화를 볼수있...
# 70    2026-03-03       4        광고 보고 포인트 받아져야 되는데 다시 광고가 재생되네요. 오류 수정바랍니다.
# 80    2026-03-03       4  일주일 방문 미션 버그만 좀 해결해라 제발 존재하지 않는 상품은 왜 있는거야 사실 ...
# 98    2026-03-03       4  오늘업뎃이후 20받기, 로또, 만보기복권이 광고후 열리지않네요. 빠른 조치바랍니다....
# ...          ...     ...                                                ...
# 9897  2025-03-08       4                                             반응이 빠름
# 9920  2025-03-07       4                                                좋아요
# 9931  2025-03-06       4                                                좋아요
# 9939  2025-03-06       4                                            빨라서 좋아요
# 9944  2025-03-06       4                               해외에서도 웹사용이 가능해서 좋습니다
#
#        app
# 16      토스
# 29      토스
# 70      토스
# 80      토스
# 98      토스
# ...    ...
# 9897  국민은행
# 9920  국민은행
# 9931  국민은행
# 9939  국민은행
# 9944  국민은행
#
# [756 rows x 4 columns]

# %%
train_df[train_df['rating'] == 3]
# Out:
#             date  rating                                        review_text  \
# 3     2026-03-05       3                                       폰트가 뭉게져서 나와요
# 13    2026-03-04       3                                         구글 페이 가즈아~
# 15    2026-03-04       3  금융앱으론 괜찮으나 앱테크로는 너무 많은것을하려다보니 버그현상이 자주일어남으로 조금...
# 27    2026-03-04       3  아니 당장 급하게 송금할 일이 있어서 돈을 보내야하는데 뭐 인증하니까 안전한 금융거...
# 28    2026-03-04       3                       도드람농협, 수협 계좌 안불러와지는데 개선 부탁좀요
# ...          ...     ...                                                ...
# 9558  2025-03-23       3                                        간단히 할수 있었네요
# 9697  2025-03-18       3                                                  굿
# 9728  2025-03-16       3  예금 상품 가입하려는데 고객확인제도 (cdd/edd) 를 해야한다고 떠서 하려고 했...
# 9790  2025-03-13       3  타금융인증서 등록했는데.. 로그인하면 튕기고 타금융인증서 해제도 안되고 개발자가 오...
# 9802  2025-03-12       3                                                  굿
#
#        app
# 3       토스
# 13      토스
# 15      토스
# 27      토스
# 28      토스
# ...    ...
# 9558  국민은행
# 9697  국민은행
# 9728  국민은행
# 9790  국민은행
# 9802  국민은행
#
# [817 rows x 4 columns]

# %%
train_df[train_df['rating'] == 2]
# Out:
#             date  rating                                        review_text  \
# 4     2026-03-04       2             진짜 토스좋아하는데 요즘 에러도 자주나고 느려지고 아주 불편해요ㅜㅜㅜ
# 8     2026-03-04       2  나만의 지금통 알림 좀 안오게하고 싶습니다. 이전에 만들었다가 해지했는데 왜이리 알...
# 10    2026-03-04       2                                     광고 광고 광고 광고 광고
# 12    2026-03-04       2           뭔 갑자기 900MB인지.. 인원은 또 왜 채용하는지.. 치과의사 앱..
# 22    2026-03-04       2  갈수록 점점 포인트가 줄어들고 안주는게 많아요 건의 했지만 광고 본다고 포인트를 주...
# ...          ...     ...                                                ...
# 9393  2025-03-31       2                                              감사합니다
# 9398  2025-03-31       2  처음 해 보아서 그런지 상당히 어렵습니다. 그냥 창구로 가서 신세 지는게 좋을 것 ...
# 9659  2025-03-19       2                                                좋아요
# 9731  2025-03-16       2                         신분증, 얼굴 인식 너무 안 되서 화가 났습니다
# 9741  2025-03-16       2                                 앱을 이용하므로 많이 편리합이다.
#
#        app
# 4       토스
# 8       토스
# 10      토스
# 12      토스
# 22      토스
# ...    ...
# 9393  국민은행
# 9398  국민은행
# 9659  국민은행
# 9731  국민은행
# 9741  국민은행
#
# [591 rows x 4 columns]

# %%
train_df[train_df['rating'] == 1]
# Out:
#             date  rating                                        review_text  \
# 0     2026-03-05       1                용량 봐라...내 폰 자원 1기가 육박하게 잡아먹고 있네 ㅎ;;
# 1     2026-03-05       1  접속이 안됩니다. 특히 3일전부터 아예 안들어가지는 시간대가 너무 길고 잦아요. 다...
# 2     2026-03-05       1  업데이트하고 나서 왜 이체할 때 비밀번호 치는 창이 투명하게 뜨는 겁니까? 투명하게...
# 5     2026-03-04       1                                 토스로또 광고 봤는데 응모가 안됨
# 6     2026-03-04       1  처음에는 다른 증권보다 ui가 편해서 섰다. 하지만 시간이 슬슬 지나니 이것저것 덕...
# ...          ...     ...                                                ...
# 9849  2025-03-11       1                        계좌개설할려고하는데 얼굴 찍는단계에서 계속 튕겨요
# 9855  2025-03-10       1                                      신분증 촬영 n번째...
# 9889  2025-03-08       1  빗썸때문에 강제로 왔는데 휴면계좌 풀려면 OTP있어야 하고 OTP를 발급하려면 정상...
# 9913  2025-03-07       1  진짜 어플 똑바로 안 만드나ㅋㅋㅋ 얼굴인증 지혼자 0.1초만에 촬영되놓곤 알아볼 수...
# 9971  2025-03-05       1  비대면 뱅킹 가입 인증이 다른 메이저 금융어플 보다 훨씬 복잡함. 주민등록초본 발급...
#
#        app
# 0       토스
# 1       토스
# 2       토스
# 5       토스
# 6       토스
# ...    ...
# 9849  국민은행
# 9855  국민은행
# 9889  국민은행
# 9913  국민은행
# 9971  국민은행
#
# [3726 rows x 4 columns]

# %%
train_df['label'] = train_df['rating'].apply(lambda x: 1 if x in [4,5] else 0)
train_df
# Out:
#             date  rating                                        review_text  \
# 0     2026-03-05       1                용량 봐라...내 폰 자원 1기가 육박하게 잡아먹고 있네 ㅎ;;
# 1     2026-03-05       1  접속이 안됩니다. 특히 3일전부터 아예 안들어가지는 시간대가 너무 길고 잦아요. 다...
# 2     2026-03-05       1  업데이트하고 나서 왜 이체할 때 비밀번호 치는 창이 투명하게 뜨는 겁니까? 투명하게...
# 3     2026-03-05       3                                       폰트가 뭉게져서 나와요
# 4     2026-03-04       2             진짜 토스좋아하는데 요즘 에러도 자주나고 느려지고 아주 불편해요ㅜㅜㅜ
# ...          ...     ...                                                ...
# 9970  2025-03-05       5                             구미공단점 직원도움으러잘가입함. 매우만족
# 9971  2025-03-05       1  비대면 뱅킹 가입 인증이 다른 메이저 금융어플 보다 훨씬 복잡함. 주민등록초본 발급...
# 9972  2025-03-05       5                                            정말 편해요~
# 9973  2025-03-05       5                                           Ui가 편하네요
# 9974  2025-03-05       5                  너무쉽게 사용할수있도록해주는 너무좋은 앱 시스템 인것같습니다
#
#        app  label
# 0       토스      0
# 1       토스      0
# 2       토스      0
# 3       토스      0
# 4       토스      0
# ...    ...    ...
# 9970  국민은행      1
# 9971  국민은행      0
# 9972  국민은행      1
# 9973  국민은행      1
# 9974  국민은행      1
#
# [9889 rows x 5 columns]

# %% [markdown]
# ## 긍정/부정 리뷰 분석 (막대그래프)

# %%
train_df['app'].unique()
# Out:
# <StringArray>
# ['토스', '국민은행']
# Length: 2, dtype: str

# %%
bank_list_dict = dict(zip(train_df['app'].unique(), ['toss', 'kb']))
bank_list_dict
# Out:
# {'토스': 'toss', '국민은행': 'kb'}

# %%
# 텍스트 정리 함수
def text_clean(text):
    temp = re.sub(r"[^가-힣a-zA-Z0-9]", " ", text)
    temp = temp.replace("  ", " ").replace("  ", " ").strip()
    return temp
