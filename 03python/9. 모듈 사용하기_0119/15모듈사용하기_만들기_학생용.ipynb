# %% [markdown]
# # 모듈 사용하기
# - 누군가가 미리 사용하기 편하게 만들어 놓은 함수, 클래스

# %% [markdown]
# ## datetime 모듈 사용하기

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 1, 19, 10, 1, 54, 736661)

# %%
now = datetime.now()

# %%
now.year
# Out:
# 2026

# %%
now.month
# Out:
# 1

# %%
now.day
# Out:
# 19

# %%
# 2026-01-19
print(f"{now.year}-{now.month:02d}-{now.day:02d}")
# Out:
# 2026-01-19

# %%
now.hour
# Out:
# 10

# %%
now.minute
# Out:
# 2

# %%
now.second
# Out:
# 4

# %% [markdown]
# * 시간을 포맷에 맞춰서 출력하기
#  - strftime(출력서식)

# %%
now.strftime("%Y.%m.%d %H:%M:%S")
# Out:
# '2026.01.19 10:02:04'

# %% [markdown]
# # OS 모듈

# %%
import os

# %%
# 내가 사용하는 컴퓨터의 기본정보 출력하기
print("현재 운영체제: ", os.name)
# Out:
# 현재 운영체제:  nt

# %%
print("현재 사용하는 폴더: ", os.getcwd())
# Out:
# 현재 사용하는 폴더:  c:\fintech04\03python\9. 모듈 사용하기_0119

# %%
print("현재 폴더 내부의 파일 리스트: " , os.listdir())
# Out:
# 현재 폴더 내부의 파일 리스트:  ['.ipynb_checkpoints', '15모듈사용하기_만들기_학생용.ipynb', '16datetime모듈사용하기_강의안.html']

# %%
print(os.listdir(), type(os.listdir()))
# Out:
# ['.ipynb_checkpoints', '15모듈사용하기_만들기_학생용.ipynb', '16datetime모듈사용하기_강의안.html'] <class 'list'>

# %%
file_list = os.listdir()
file_list[0]
# Out:
# '.ipynb_checkpoints'

# %%
for file in file_list:
    print(file, type(file))
    if file[-5:] == "ipynb":
        print(file)
# Out:
# .ipynb_checkpoints <class 'str'>
# 15모듈사용하기_만들기_학생용.ipynb <class 'str'>
# 15모듈사용하기_만들기_학생용.ipynb
# 16datetime모듈사용하기_강의안.html <class 'str'>

# %% [markdown]
# * data 폴더에서 csv 파일 목록만 가져오기

# %%
os.listdir("../data")
# Out:
# ['14JSON언패킹2_호텔스닷컴리뷰json구조.txt',
#  'com_kbstar_kbbank.json',
#  'hotels_korea_reviews_text.json',
#  'test.txt',
#  'test2.txt',
#  '서울특별시_관광지입장정보_2011_2016.json',
#  '전국치킨집리스트.json']

# %%
os.listdir("../")
# Out:
# ['.gitignore',
#  '.ipynb_checkpoints',
#  '1. Python 문법 기초_0106',
#  '2. 문자열과 문자열 함수_0107',
#  '3. 리스트와 튜플_0108',
#  '4. if_else 조건문_0109',
#  '5. 리스트 표현식_파일 읽기쓰기_0112',
#  '6. JSON 언패킹_0114',
#  '7. 함수만들기_0115',
#  '8. 클래스만들기_0116',
#  '9. 모듈 사용하기_0119',
#  'data']

# %%
os.getcwd()
# Out:
# 'c:\\fintech04\\03python\\9. 모듈 사용하기_0119'

# %%
os.mkdir("testdir")

# %%
os.rmdir("testdir")

# %% [markdown]
# # 폴더가 있는지 확인하고 없으면 폴더 생성하기

# %%
dir_name = "testdir"
if not os.path.exists(dir_name):
    os.mkdir(dir_name)
    print(f"{dir_name}을 생성했습니다.")
else:
    print(f"{dir_name}이 이미 있습니다.")
# Out:
# testdir이 이미 있습니다.

# %%
import myfunc
# Out:
# Traceback (most recent call last):
#
#   File ~\miniforge3\envs\fintech\lib\site-packages\IPython\core\interactiveshell.py:3579 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[46], line 1
#     import myfunc
#
#   File c:\fintech04\03python\9. 모듈 사용하기_0119\myfunc.py:14
#     self.num1 = num1
#     ^
# IndentationError: expected an indented block after function definition on line 13

# %% [markdown]
# # 모듈에서 일부 함수나 클래스만 따로 불러올 때

# %%
from myfunc import add
# Out:
# Traceback (most recent call last):
#
#   File ~\miniforge3\envs\fintech\lib\site-packages\IPython\core\interactiveshell.py:3579 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[48], line 1
#     from myfunc import add
#
#   File c:\fintech04\03python\9. 모듈 사용하기_0119\myfunc.py:14
#     self.num1 = num1
#     ^
# IndentationError: expected an indented block after function definition on line 13

# %% [markdown]
# ---

# %% [markdown]
# # 연습문제

# %%
from datetime import datetime, date
print(type(date.today()))
print(type(datetime.now()))
# Out:
# <class 'datetime.date'>
# <class 'datetime.datetime'>

# %%
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2026, 1, 19, 17, 42, 41, 865017)

# %%
d = datetime.now()

# %%
print(f"{d.year}-{d.month:02d}-{d.day:02d}")
# Out:
# 2026-01-19

# %%
# 2026-01-19
print(f"{now.year}-{now.month:02d}-{now.day:02d}")
