# %% [markdown]
# # 모듈 사용하기
# * 누군가가 미리 사용하기 편하게 만들어 놓은 함수, 클래스
# * import 명령을 통해서 프로그램 가장 위에서 모듈을 불러와 사용할 수 있음
# * 모듈에 너무 많은 기능이 있는경우 from 모듈명 import 함수/메서드명 형식으로 일부 기능만 불러올 수도 있음.
# * 모듈은 사용자가 직접 만들 수도 있음.
# * 사용자 모듈을 불러올 때는 실행하는 파일 같은 위치에 있어야 함

# %% [markdown]
# # datetime 모듈 사용하기

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 1, 19, 10, 1, 14, 849288)

# %%
now = datetime.now()

# %%
now.year
# Out:
# 2026

# %%
now.month
# Out:
# 1

# %%
now.day
# Out:
# 19

# %%
print("now", type(now))
print("now.year", type(now.year))
print("f'{now.year}'", type(f"{now.year}"))
# Out:
# now <class 'datetime.datetime'>
# now.year <class 'int'>
# f'{now.year}' <class 'str'>

# %%
# 2026-01-19
print(f"{now.year}-{now.month:02d}-{now.day:02d}")
# Out:
# 2026-01-19

# %%
now.hour
# Out:
# 10

# %%
now.minute
# Out:
# 1

# %%
now.second
# Out:
# 51

# %% [markdown]
# * 시간을 포멧에 맞춰 출력하기
#   * strftime(출력서식)

# %%
now.strftime("%Y.%m.%d %H:%M:%S")
# Out:
# '2026.01.19 10:01:51'

# %%
now.strftime("%y.%h.%d %H:%M:%S")
# Out:
# '26.Jan.19 10:01:51'

# %% [markdown]
# # OS 모듈

# %%
import os

# %%
# 내가 사용하는 컴퓨터의 기본정보 출력하기
print("현재 운영체제: ", os.name)
# Out:
# 현재 운영체제:  nt

# %%
# os.getcwd() - current working directory
print("현재 사용하는 폴더: ", os.getcwd())
# Out:
# 현재 사용하는 폴더:  c:\fintech4\03python

# %%
# 파일 리스트
print("현재 폴더 내부의 파일 리스트: ", os.listdir())
# Out:
# 현재 폴더 내부의 파일 리스트:  ['.ipynb_checkpoints', '00주피터노트북_사용법.ipynb', '00파이썬가상환경_miniforge.html', '00파이썬가성환경_miniforge_연습문제.html', '01_파이썬문법기초.ipynb', '02_파이썬의_자료형.ipynb', '03_Miniforge_주피터노트북 설치 및 설정.pdf', '03연산자의_종류와_활용.ipynb', '04문자열과 문자열 함수.ipynb', '05리스트와_튜플사용하기_시퀀스객체.ipynb', '06딕셔너리 사용하기.ipynb', '07서식지정자, format 메서드, f-string.ipynb', '08if_else조건문.ipynb', '09반복문_for_while.ipynb', '10리스트표현식_파일읽기쓰기.ipynb', '11JSON파일정리해서 DataFrame으로 만들어 csv 파일로 저장하기.ipynb', '12호텔스닷컴_JSON_언패킹_과제.ipynb', '13함수만들기_예외처리.ipynb', '14클래스만들기.ipynb', '15모듈사용하기_만들기.ipynb', 'data', 'styles.css', 'test.py', '문자열_연습문제.txt', '주피터테스트.ipynb']

# %%
# ipynb 파일 목록만 만들기
print(os.listdir(), type(os.listdir()))
# Out:
# ['.ipynb_checkpoints', '00주피터노트북_사용법.ipynb', '00파이썬가상환경_miniforge.html', '00파이썬가성환경_miniforge_연습문제.html', '01_파이썬문법기초.ipynb', '02_파이썬의_자료형.ipynb', '03_Miniforge_주피터노트북 설치 및 설정.pdf', '03연산자의_종류와_활용.ipynb', '04문자열과 문자열 함수.ipynb', '05리스트와_튜플사용하기_시퀀스객체.ipynb', '06딕셔너리 사용하기.ipynb', '07서식지정자, format 메서드, f-string.ipynb', '08if_else조건문.ipynb', '09반복문_for_while.ipynb', '10리스트표현식_파일읽기쓰기.ipynb', '11JSON파일정리해서 DataFrame으로 만들어 csv 파일로 저장하기.ipynb', '12호텔스닷컴_JSON_언패킹_과제.ipynb', '13함수만들기_예외처리.ipynb', '14클래스만들기.ipynb', '15모듈사용하기_만들기.ipynb', 'data', 'styles.css', 'test.py', '문자열_연습문제.txt', '주피터테스트.ipynb'] <class 'list'>

# %%
file_list = os.listdir()
file_list[0]
# Out:
# '.ipynb_checkpoints'

# %%
ipynb_list = []
for file in file_list:
#     print(file, type(file))
    if file[-5:] == "ipynb":
        ipynb_list.append(file)
ipynb_list
# Out:
# ['15모듈사용하기_만들기.ipynb', '15모듈사용하기_만들기_학생용.ipynb']

# %% [markdown]
# * data 폴더에서 csv 파일 목록만 가져오기

# %%
csv_list = []
for file in os.listdir("../data"):
#     print(file)
    if file[-3:] == "csv":
        csv_list.append(file)
csv_list
# Out:
# []

# %%
# os.listdir("../")

# %%
os.getcwd()
# Out:
# 'c:\\fintech4\\03python'

# %%
# 현재 위치에서 폴더 만들기
os.mkdir("testdir")

# %%
# 현재 위치에서 폴더 삭제하기
os.rmdir("testdir2")

# %% [markdown]
# # 폴더가 있는지 확인하고 없으면 폴더 생성하기

# %%
dir_name = "testdir"
if not os.path.exists(dir_name):
    os.mkdir(dir_name)
    print(f"{dir_name}을 생성했습니다.")
else:
    print(f"{dir_name}이 이미 있습니다.")
# Out:
# testdir2이 이미 있습니다.

# %%
os.getcwd()
# Out:
# 'c:\\fintech4\\03python'

# %% [markdown]
# # 내 모듈 만들기
# * .py 형식으로 내 모듈을 만들 수 있다.
# * .py 파일 안에는 함수를 정의해야 한다.
# * .py 파일은 모듈을 불러오는 파일과 같은 위치에 있어야 한다.

# %% [markdown]
# * Cal 클래스와 add라는 함수를 모듈로 만들고 불러와서 사용하기

# %%
import myfunc

# %%
add(3, 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 add(3, 5)
#
# NameError: name 'add' is not defined

# %%
myfunc.add(3,5)
# Out:
# 8

# %%
sam = myfunc.Cal(3, 5)

# %%
sam.add()
# Out:
# 8

# %%
sam.sub()
# Out:
# -2

# %%
sam.mul()
# Out:
# 15

# %%
sam.div()
# Out:
# 0.6

# %% [markdown]
# # 약칭을 사용해서 모듈명 축약해서 사용하기

# %%
import myfunc as mf

# %%
mf.add(3, 7)
# Out:
# 10

# %%
sam2 = mf.Cal(3, 7)

# %%
sam2.add()
# Out:
# 10

# %% [markdown]
# # 모듈에서 일부 함수나 클래스만 따로 불러올 때
# ```python
# from 모듈명 import 함수/클래스명, 함수2/클래스2명
# ```

# %%
from myfunc import add, Cal

# %%
add(10, 20)
# Out:
# 30

# %%
dul = Cal(10, 0)

# %%
dul.div()
# Out:
# 0

# %%
from myfunc import text_clean

# %%
test = "%$@%@$^ 테스트 \n 문자열 \t $@ 입니다."

# %%
text_clean(test)
# Out:
# '테스트 문자열 입니다'
