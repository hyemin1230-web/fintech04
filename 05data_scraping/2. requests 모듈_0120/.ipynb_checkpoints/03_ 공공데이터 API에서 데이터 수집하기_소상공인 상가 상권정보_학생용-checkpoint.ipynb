# %% [markdown]
# # 소상공인 상가(상권)정보 api 링크
# https://www.data.go.kr/data/15012005/openapi.do

# %%
import os

# %%
import requests
import pandas as pd

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# python-dotenv could not parse statement starting at line 3
# True

# %%
os.getenv("service_key")

# %%
url = "https://apis.data.go.kr/B553077/api/open/sdsc2/storeListInUpjong"
payload = dict(divid="indsSclsCd", key="I21006", numOfRows=2, pageNo=1, type="json", serviceKey=os.getenv("service_key"))
r = requests.get(url, params=payload)
print(r.url)
print(r.status_code)
# Out:
# https://apis.data.go.kr/B553077/api/open/sdsc2/storeListInUpjong?divid=indsSclsCd&key=I21006&numOfRows=2&pageNo=1&type=json
# 401

# %%
for item in response['body']['items']:
    for key, value in item.items():
        result.setdefault(key, []).append(value)
df = pd.dataframe(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 for item in response['body']['items']:
#       2     for key, value in item.items():
#       3         result.setdefault(key, []).append(value)
#
# TypeError: string indices must be integers

# %%
if response['body']['totalCount']%1000 ==0:
    total_pages = response['body']['totalCount'] //1000
else:
    total_pages = response['body']['totalCount'] // 1000 + 1
total_pages
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 if response['body']['totalCount']%1000 ==0:
#       2     total_pages = response['body']['totalCount'] //1000
#       3 else:
#
# TypeError: string indices must be integers

# %%
page = 1
    while True:
    if response['body']['totalCount']%1000 ==0:
    total_pages = response['body']['totalCount'] //1000
    else:
    total_pages = response['body']['totalCount'] // 1000 + 1
# Out:
#   Cell In[19], line 2
#     while True:
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # 업종 데이터를 불러와서 업종별 가게 리스트 csv파일 만들기
# - shops_data 폴더에 저장
# - 업종이름_가게리스트,csv

# %%
#업종파일 xlsx 파일 불러와서 업종 리스트 추출하기
# !pip install openpyxl

# %%
upjong_list = pd.read_excel("./소상공인시장진흥공단_상가(상권)정보_업종분류(2302)_및_연계표_v1.xlsx", header = 1)
upjong_codes = upjong_list['소분류코드']
upjong_name = upjong_list['소분류명']

# %%
for code in upjong_codes:
    print(code)
# Out:
# G20201
# G20202
# G20301
# G20404
# G20405
# G20499
# G20501
# G20502
# G20503
# G20504
# G20505
# G20506
# G20507
# G20508
# G20509
# G20601
# G20602
# G20603
# G20604
# G20701
# G20801
# G20802
# G20803
# G20901
# G20902
# G20903
# G20904
# G20905
# G20906
# G20907
# G20908
# G20909
# G20910
# G20911
# G21001
# G21002
# G21003
# G21099
# G21101
# G21201
# G21202
# G21203
# G21301
# G21302
# G21303
# G21304
# G21305
# G21306
# G21401
# G21402
# G21403
# G21501
# G21502
# G21503
# G21601
# G21602
# G21603
# G21701
# G21801
# G21802
# G21901
# G22001
# G22199
# G22201
# I10101
# I10102
# I10103
# I10104
# I10201
# I10299
# I20101
# I20102
# I20103
# I20104
# I20105
# I20106
# I20107
# I20108
# I20109
# I20110
# I20111
# I20112
# I20113
# I20199
# I20201
# I20202
# I20301
# I20302
# I20303
# I20399
# I20401
# I20402
# I20403
# I20499
# I20501
# I20599
# I20601
# I20701
# I20702
# I21001
# I21002
# I21003
# I21004
# I21005
# I21006
# I21007
# I21008
# I21099
# I21101
# I21102
# I21103
# I21104
# I21201
# L10203
# M10301
# M10302
# M10303
# M10306
# M10307
# M10399
# M10401
# M10402
# M10499
# M10501
# M10502
# M10503
# M10504
# M10599
# M10601
# M10703
# M10901
# M10902
# M10903
# M10904
# M10999
# M11101
# M11201
# M11202
# M11203
# M11204
# M11301
# M11401
# M11502
# M11504
# N10101
# N10201
# N10202
# N10203
# N10301
# N10401
# N10402
# N10403
# N10501
# N10599
# N10703
# N10799
# N10802
# N10805
# N10901
# N10999
# N11001
# N11002
# N11003
# N11004
# N11099
# N11101
# N11102
# N11199
# P10501
# P10601
# P10603
# P10605
# P10607
# P10609
# P10611
# P10613
# P10615
# P10617
# P10619
# P10621
# P10623
# P10625
# P10627
# P10629
# P10701
# P10799
# Q10101
# Q10102
# Q10103
# Q10104
# Q10105
# Q10201
# Q10202
# Q10203
# Q10204
# Q10205
# Q10206
# Q10207
# Q10208
# Q10209
# Q10210
# Q10211
# Q10212
# Q10402
# R10202
# R10306
# R10307
# R10308
# R10309
# R10310
# R10311
# R10312
# R10313
# R10314
# R10316
# R10402
# R10404
# R10405
# R10406
# R10407
# R10408
# R10409
# R10410
# R10414
# R10499
# S20101
# S20201
# S20301
# S20302
# S20401
# S20501
# S20601
# S20602
# S20603
# S20699
# S20701
# S20702
# S20703
# S20801
# S20802
# S20803
# S20901
# S20902
# S21001
# S21002
# S21101
# S21105

# %%
print(upjong_name)
# Out:
# 0             타이어 소매업
# 1          자동차 부품 소매업
# 2      모터사이클 및 부품 소매업
# 3                슈퍼마켓
# 4                 편의점
#             ...
# 242            셀프 빨래방
# 243              장례식장
# 244        화장터/묘지/납골당
# 245              예식장업
# 246        결혼 상담 서비스업
# Name: 소분류명, Length: 247, dtype: object
